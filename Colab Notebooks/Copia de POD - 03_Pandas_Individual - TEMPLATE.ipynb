# %% [markdown]
# *   **Año:** 2024
# *   **Alumno/a:** Stefano Iaizzo
# *   **Legajo:** 42255420

# %% [markdown]
# texto en cursiva# Pandas
# A continuación, cada celda va a pedir algo distinto. Por favor, realizarlo con la menor cantidad de lineas posibles y con NumPy.

# %% [markdown]
# Importar `pandas` con el alias `pd` e imprimir la versión instalada.

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde cada linea represente un diccionario.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
data = [
       {'Index':'9','Nombre': 'Brown, James','Edad' : '43','DNI': '30123444'},
       {'Index':'3','Nombre': 'Hamkel, Louis V.','Edad' : '29','DNI': '44555666'},
       {'Index':'7','Nombre': 'Baptista, Carlos','Edad' : '28','DNI': '43120111'}]
df = pd.DataFrame(data)
print(df)
# Out:
#   Index            Nombre Edad       DNI
# 0     9      Brown, James   43  30123444
# 1     3  Hamkel, Louis V.   29  44555666
# 2     7  Baptista, Carlos   28  43120111

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde todas las lineas esten dentro de un solo diccionario.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
data= {
        'Nombre': ['Brown, James', 'Hamkel, Louis V.', 'Baptista, Carlos'],
        'Edad': ['43', '29', '28'],
        'DNI': ['30123444', '44555666', '43120111']}

df = pd.DataFrame(data,index=['9','3','7'])
print(df)
# Out:
#              Nombre Edad       DNI
# 9      Brown, James   43  30123444
# 3  Hamkel, Louis V.   29  44555666
# 7  Baptista, Carlos   28  43120111

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde se usen unicamente listas.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
nombres = ['Brown, James','Hamkel, Louis V.','Baptista, Carlos']
edades = ['43','29','28']
dni = ['30123444','44555666','43120111']

df = pd.DataFrame({'Nombres':nombres,'Edades':edades,'DNI':dni},index = ['9','3','7'])
print(df)
# Out:
#             Nombres Edades       DNI
# 9      Brown, James     43  30123444
# 3  Hamkel, Louis V.     29  44555666
# 7  Baptista, Carlos     28  43120111

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde se usen unicamente `Series`.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
nombres = pd.Series(['Brown, James','Hamkel, Louis V.','Baptista, Carlos'])
edad = pd.Series(['43','29','28'])
dni = pd.Series(['30123444','44555666','43120111'])

df = pd.DataFrame([nombres, edad, dni],index = [9,3,7])
df.columns = ['Nombres','Edades','DNI']
print(df)
# Out:
#         Nombres            Edades               DNI
# 9  Brown, James  Hamkel, Louis V.  Baptista, Carlos
# 3            43                29                28
# 7      30123444          44555666          43120111

# %% [markdown]
# Reutilice cualquiera de los dataframe hechos anteriormente pero agregue la columna `fecha` con el tipo de dato relacionado a fechas.
#
# | _Index_ | **nombre**       | **edad** | **dni**  | **fecha**  |
# |---------|------------------|----------|----------|------------|
# | 9       | Brown, James     | 43       | 30123444 | 12/08/1981 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 | 10/04/1995 |
# | 7       | Baptista, Carlos | 28       | 43120111 | 28/05/1996 |

# %%
data= {
        'Nombre': ['Brown, James', 'Hamkel, Louis V.', 'Baptista, Carlos'],
        'Edad': ['43', '29', '28'],
        'DNI': ['30123444', '44555666', '43120111'],
        'Fecha':['12/08/1981','10/04/1995','28/05/1996']}

df = pd.DataFrame(data,index=['9','3','7'])
print(df)
# Out:
#              Nombre Edad       DNI       Fecha
# 9      Brown, James   43  30123444  12/08/1981
# 3  Hamkel, Louis V.   29  44555666  10/04/1995
# 7  Baptista, Carlos   28  43120111  28/05/1996

# %% [markdown]
# Ejecute la siguiente celda. Se va a descargar un archivo llamado `u.user`.

# %%
# !wget https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
# Out:
# --2024-09-17 23:51:19--  https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22667 (22K) [text/plain]
# Saving to: ‘u.user’
#
# u.user              100%[===================>]  22.14K  --.-KB/s    in 0s
#
# 2024-09-17 23:51:20 (84.2 MB/s) - ‘u.user’ saved [22667/22667]

# %% [markdown]
# Lea el archivo con pandas y muestre las primeras 5 filas.

# %%
df = pd.read_csv('u.user', sep='|')
df.head(5)
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# Utilice la columna `user_id` como indice y saque dicha columna del dataframe

# %%
df_index = df.set_index('user_id')
user_id = df[['user_id']]
df_index
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# ¿Cuantas categorias de trabajos hay?

# %%
categorias = df['occupation'].unique()
categorias = len(categorias)
print(categorias)
# Out:
# 21

# %% [markdown]
#  Reporte el porcentaje de personas que tiene cada ocupación.

# %%
ocupaciones = df['occupation'].value_counts()

porcentajes = (ocupaciones / len(df)) * 100

print(porcentajes)
# Out:
# occupation
# student          20.784730
# other            11.134677
# educator         10.074231
# administrator     8.377519
# engineer          7.104984
# programmer        6.998940
# librarian         5.408271
# writer            4.772004
# executive         3.393425
# scientist         3.287381
# artist            2.969247
# technician        2.863203
# marketing         2.757158
# entertainment     1.908802
# healthcare        1.696713
# retired           1.484624
# lawyer            1.272534
# salesman          1.272534
# none              0.954401
# homemaker         0.742312
# doctor            0.742312
# Name: count, dtype: float64

# %% [markdown]
# Reporte el promedio de edad de los estudiantes usando indexeo booleano.
#
# > Añadir blockquote

# %%
estudiantes = df[df['occupation'] == 'student']
promedio_edad = estudiantes['age'].mean()
print(promedio_edad)
# Out:
# 22.081632653061224

# %% [markdown]
# Mostrar, con una sola linea y sin importar `matplotlib`, un histograma de las edades de las personas que son administradores.

# %%
df[df['occupation'] == 'administrator']['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Reemplace, sin usar `for`, en la columna `gender` `F` por `female` y `M` por `male`.

# %%
df['gender'] = df['gender'].replace({'F': 'female', 'M': 'male'})
df
# Out:
#      user_id  age  gender     occupation zip_code
# 0          1   24    male     technician    85711
# 1          2   53  female          other    94043
# 2          3   23    male         writer    32067
# 3          4   24    male     technician    43537
# 4          5   33  female          other    15213
# ..       ...  ...     ...            ...      ...
# 938      939   26  female        student    33319
# 939      940   32    male  administrator    02215
# 940      941   20    male        student    97229
# 941      942   48  female      librarian    78209
# 942      943   22    male        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# # Yahoo! Finance

# %% [markdown]
# Vamos a analizar acciones. La siguiente linea accede a Yahoo Finance y devuelve un DataFrame con los valores de la acción cada dia desde el 1980.

# %%
import yfinance as yf
dataframe = yf.download('AAPL', start="1980-01-01", end="2030-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ¿Cual es el registro mas viejo? Imprimirlo.

# %%
registro_mas_viejo = dataframe.iloc[0]
print(registro_mas_viejo)
# Out:
# Open         1.283480e-01
# High         1.289060e-01
# Low          1.283480e-01
# Close        1.283480e-01
# Adj Close    9.894321e-02
# Volume       4.690336e+08
# Name: 1980-12-12 00:00:00, dtype: float64

# %% [markdown]
# Cree la columna `Average` tal que
#
# $$Average =  \frac{High-Low}{2}$$
#
# y muestre con un histograma dicha columna.

# %%
import matplotlib.pyplot as plt

dataframe['Average'] = (dataframe['High'] - dataframe['Low']) / 2
plt.hist(dataframe['Average'])
plt.title('Histograma de la Columna Average')
plt.xlabel('Average')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Con `matplotlib`, muestre como `Average` fue evolucionando *al final de cada año*.

# %%
dataframe['Average'] = (dataframe['High'] - dataframe['Low']) / 2
dataframe_final_year = dataframe.resample('Y').last()
plt.plot(dataframe_final_year.index, dataframe_final_year['Average'])
plt.title('Evolución del Average de AAPL al Final de Cada Año')
plt.xlabel('Año')
plt.ylabel('Average')
plt.grid()

# %% [markdown]
# Muestre con un gráfico de barras, como el volumen fue cambiando *año a año*.

# %%
dataframe['Year'] = dataframe.index.year
volume_yearly = dataframe.groupby('Year')['Volume'].sum()


plt.figure(figsize=(12, 6))
plt.bar(volume_yearly.index, volume_yearly.values, color='red')
plt.title('Cambio del Volumen de AAPL Año a Año')
plt.xlabel('Año')
plt.ylabel('Volumen Total')
plt.show()

# %% [markdown]
# # Cancelaciones y Delays de vuelos del 2015

# %% [markdown]
# Creese una cuenta en Kaggle e importe los archivos del dataset del siguiente link: https://www.kaggle.com/datasets/usdot/flight-delays. Cree los dataframes `airlines`, `airports`, y `flights` apartir de esos archivos.

# %%
df = pd.read_csv("/content/airlines.csv")
df2 = pd.read_csv("/content/airports.csv")
df3 = pd.read_csv("/content/flights.csv")
airlines = df
airports = df2
flights = df3

# %% [markdown]
# Combine (*join*) las tablas `airlines`, `airports`, y `flights` en una sola tabla.

# %%
flights_airlines = pd.merge(flights, airlines, left_on='AIRLINE', right_on='IATA_CODE', how='left')

flights_airports_origin = pd.merge(flights_airlines, airports, left_on='ORIGIN_AIRPORT', right_on='IATA_CODE', how='left', suffixes=('_origin', '_origin_airport'))

print(flights_airports_origin.columns)

flights_airports_final = pd.merge(flights_airports_origin, airports, left_on='DESTINATION_AIRPORT', right_on='IATA_CODE', how='left', suffixes=('_origin', '_destination'))

print(flights_airports_final.columns)

flights_airports_final = flights_airports_final.loc[:, ~flights_airports_final.columns.str.contains('IATA_CODE')]

print(flights_airports_final.head())
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE_x', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY', 'IATA_CODE_origin', 'AIRLINE_y',
#        'IATA_CODE_origin_airport', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY',
#        'LATITUDE', 'LONGITUDE'],
#       dtype='object')
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE_x', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY', 'IATA_CODE_origin', 'AIRLINE_y',
#        'IATA_CODE_origin_airport', 'AIRPORT_origin', 'CITY_origin',
#        'STATE_origin', 'COUNTRY_origin', 'LATITUDE_origin', 'LONGITUDE_origin',
#        'IATA_CODE', 'AIRPORT_destination', 'CITY_destination',
#        'STATE_destination', 'COUNTRY_destination', 'LATITUDE_destination',
#        'LONGITUDE_destination'],
#       dtype='object')
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1          4.0        AS           98.0      N407AS
# 1  2015      1    1          4.0        AA         2336.0      N3KUAA
# 2  2015      1    1          4.0        US          840.0      N171US
# 3  2015      1    1          4.0        AA          258.0      N3HYAA
# 4  2015      1    1          4.0        AS          135.0      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  STATE_origin  \
# 0            ANC                 SEA                  5.0  ...            AK
# 1            LAX                 PBI                 10.0  ...            CA
# 2            SFO                 CLT                 20.0  ...            CA
# 3            LAX                 MIA                 20.0  ...            CA
# 4            SEA                 ANC                 25.0  ...            WA
#
#    COUNTRY_origin  LATITUDE_origin  LONGITUDE_origin  \
# 0             USA         61.17432        -149.99619
# 1             USA         33.94254        -118.40807
# 2             USA         37.61900        -122.37484
# 3             USA         33.94254        -118.40807
# 4             USA         47.44898        -122.30931
#
#                            AIRPORT_destination  CITY_destination  \
# 0         Seattle-Tacoma International Airport           Seattle
# 1             Palm Beach International Airport   West Palm Beach
# 2      Charlotte Douglas International Airport         Charlotte
# 3                  Miami International Airport             Miami
# 4  Ted Stevens Anchorage International Airport         Anchorage
#
#    STATE_destination  COUNTRY_destination  LATITUDE_destination  \
# 0                 WA                  USA              47.44898
# 1                 FL                  USA              26.68316
# 2                 NC                  USA              35.21401
# 3                 FL                  USA              25.79325
# 4                 AK                  USA              61.17432
#
#    LONGITUDE_destination
# 0             -122.30931
# 1              -80.09559
# 2              -80.94313
# 3              -80.29056
# 4             -149.99619
#
# [5 rows x 44 columns]

# %% [markdown]
# ¿Cuantos vuelos fueron al aeropuerto JFK?

# %%
flights_jfk = flights[flights['DESTINATION_AIRPORT'] == 'JFK']

num_vuelos_jfk = flights_jfk.shape[0]

print(f'Número de vuelos al aeropuerto JFK: {num_vuelos_jfk}')
# Out:
# Número de vuelos al aeropuerto JFK: 1897

# %% [markdown]
# ¿Cuantos vuelos hizo la aerolinea AA?

# %%
flights_aa = flights[flights['AIRLINE'] == 'AA']

num_vuelos_aa = flights_aa.shape[0]

print(f'Número de vuelos realizados por la aerolínea AA: {num_vuelos_aa}')
# Out:
# Número de vuelos realizados por la aerolínea AA: 9772

# %% [markdown]
# ¿Que aerolineas (las primeras 5) tuvo la menor cantidad de vuelos con atrasos? Imprimirlas.

# %%
flights_with_delay = flights[flights['DEPARTURE_DELAY'] > 0]

delayed_flights_by_airline = flights_with_delay.groupby('AIRLINE').size()

delayed_flights_sorted = delayed_flights_by_airline.sort_values().head(5)

print(delayed_flights_sorted)
# Out:
# AIRLINE
# VX     423
# HA     576
# F9    1041
# AS    1048
# NK    1170
# dtype: int64

# %% [markdown]
# ¿Que aerolineas (las primeras 5) tuvo la mayor cantidad de vuelos con atrasos? Imprimirlas.

# %%
flights_with_delay = flights[flights['DEPARTURE_DELAY'] > 0]

delayed_flights_by_airline = flights_with_delay.groupby('AIRLINE').size()

delayed_flights_sorted = delayed_flights_by_airline.sort_values(ascending=False).head(5)

print(delayed_flights_sorted)
# Out:
# AIRLINE
# WN    14427
# UA     6066
# DL     5770
# AA     5500
# EV     5473
# dtype: int64

# %% [markdown]
# Haga un resumen de las razones por la cual los vuelos se atrasan.

# %%
#Las principales razones que marca el dataset son las siguientes:
#AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY

# %% [markdown]
# Compruebe si hay columnas con celdas vacias.

# %%
missing_values = flights.isnull().sum()

print(missing_values[missing_values > 0])
# Out:
# DAY_OF_WEEK                 1
# AIRLINE                     1
# FLIGHT_NUMBER               1
# TAIL_NUMBER               173
# ORIGIN_AIRPORT              1
# DESTINATION_AIRPORT         1
# SCHEDULED_DEPARTURE         1
# DEPARTURE_TIME           2355
# DEPARTURE_DELAY          2355
# TAXI_OUT                 2429
# WHEELS_OFF               2429
# SCHEDULED_TIME              1
# ELAPSED_TIME             2681
# AIR_TIME                 2681
# DISTANCE                    1
# WHEELS_ON                2506
# TAXI_IN                  2506
# SCHEDULED_ARRIVAL           1
# ARRIVAL_TIME             2506
# ARRIVAL_DELAY            2681
# DIVERTED                    1
# CANCELLED                   1
# CANCELLATION_REASON    101000
# AIR_SYSTEM_DELAY        67813
# SECURITY_DELAY          67813
# AIRLINE_DELAY           67813
# LATE_AIRCRAFT_DELAY     67813
# WEATHER_DELAY           67813
# dtype: int64

# %% [markdown]
# Haga una imputación de datos COMPLETA del dataframe. Pueden escojer cualquier estrategia y no necesariamente todas las columnas deben seguir la misma estrategia.

# %%
from sklearn.impute import SimpleImputer

numerical_columns = flights.select_dtypes(include=['float64', 'int64']).columns
numerical_imputer = SimpleImputer(strategy='median')

flights[numerical_columns] = numerical_imputer.fit_transform(flights[numerical_columns])

categorical_columns = flights.select_dtypes(include=['object']).columns
categorical_imputer = SimpleImputer(strategy='most_frequent')

flights[categorical_columns] = categorical_imputer.fit_transform(flights[categorical_columns])

missing_values_after_imputation = flights.isnull().sum()

print(missing_values_after_imputation[missing_values_after_imputation > 0])
# Out:
# Series([], dtype: int64)
